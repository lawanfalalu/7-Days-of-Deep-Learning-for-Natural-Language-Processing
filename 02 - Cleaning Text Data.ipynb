# %% [markdown]
# <img src="resources\deep learnig for nlp.PNG" width='10%'>

# %% [markdown]
# ## Cleaning Text Data: Text can be messy
# - Upper and lower case characters.
# - Punctuation within and around words.
# - Numbers such as amounts and dates.
# - Spelling mistakes and regional variations.
# - Unicode characters
# - and much more...

# %% [markdown]
# Generally, we refer to the process of turning raw text into something we can model as __tokenization__,
# where we are left with a list of __words__ or __tokens__.

# %% [markdown]
# Exploring both manual and NLTK approaches to tokenization of a free classical book on the [Project Gutenberg](http://www.gutenberg.org/).

# %% [markdown]
# url = "https://www.gutenberg.org/cache/epub/32884/pg32884.txt"
#
# ### Manual Tokenization:

# %%
import urllib.request
url = "https://www.gutenberg.org/cache/epub/32884/pg32884.txt"


with urllib.request.urlopen(url) as f:
    data = f.read().decode('utf-8')

# %%
f = open(r'resources/Ideas of Good and Evil.txt','w',encoding='utf-8')

# %%
f.write(data)
# Out:
# 340437

# %%
filepath = 'resources/Ideas of Good and Evil.txt'
file = open(filepath,'rt', encoding='utf-8')
text = file.read()
file.close()
# split into words by white space
words = text.split()
# convert to lowercase
words = [word.lower() for word in words]

# %%
# displaying the first 20 tokens or words
words[:20]
# Out:
# ['\ufeffthe',
#  'project',
#  'gutenberg',
#  'ebook',
#  'of',
#  'ideas',
#  'of',
#  'good',
#  'and',
#  'evil',
#  'this',
#  'ebook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'in']

# %%
# displaying the last 20 tokens or words

words[-20:]
# Out:
# ['how',
#  'to',
#  'help',
#  'produce',
#  'our',
#  'new',
#  'ebooks,',
#  'and',
#  'how',
#  'to',
#  'subscribe',
#  'to',
#  'our',
#  'email',
#  'newsletter',
#  'to',
#  'hear',
#  'about',
#  'new',
#  'ebooks.']

# %%
len(words)
# Out:
# 59694

# %% [markdown]
# > Let's generate a wordcloud for our data. A wordcloud is a visual representation of textual data. It is a collection, or cluster of words depicted in different sizes. The bigger and bolder the word appears, the more often it's mentioned within our textual data and the more important it is.

# %%
# Displaying 
from wordcloud import WordCloud
import matplotlib.pyplot as plt

all_text = ' '.join(words)

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # No axes for the word cloud
plt.show()

# %% [markdown]
# ## Using NLTK to tokenize text

# %%
import nltk
nltk.data.path.append(r'C:\Users\DELL\AppData\Roaming\nltk_data')

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
tokens = word_tokenize(text, language='english', preserve_line=True)

# %%
len(tokens)
# Out:
# 66089

# %%
print(f"Manual tokenizer gives {len(words)}, while nltk tokenizer gives {len(tokens)}")
print(f"Is manual tokenization gives the same results with nltk ? {len(tokens) == len(words)}")
print(f"the difference is {len(tokens) - len(words)}")
# Out:
# Manual tokenizer gives 59694, while nltk tokenizer gives 66089
# Is manual tokenization gives the same results with nltk ? False
# the difference is 6395

# %%
# displaying the first 20 tokens or words
tokens[:20]
# Out:
# ['\ufeffThe',
#  'Project',
#  'Gutenberg',
#  'eBook',
#  'of',
#  'Ideas',
#  'of',
#  'Good',
#  'and',
#  'Evil',
#  'This',
#  'ebook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'in']

# %%
# displaying the last 20 tokens or words
tokens[-20:]
# Out:
# ['help',
#  'produce',
#  'our',
#  'new',
#  'eBooks',
#  ',',
#  'and',
#  'how',
#  'to',
#  'subscribe',
#  'to',
#  'our',
#  'email',
#  'newsletter',
#  'to',
#  'hear',
#  'about',
#  'new',
#  'eBooks',
#  '.']

# %%
# Displaying 
all_text = ' '.join(tokens)

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # No axes for the word cloud
plt.show()
