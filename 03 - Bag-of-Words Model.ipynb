# %% [markdown]
# <img src="resources\deep learnig for nlp.PNG" width='10%'>

# %% [markdown]
# ## Bag-of-Words Model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Reading our text file (book)
filepath = 'resources/Ideas of Good and Evil.txt'
with open(filepath,'rt', encoding='utf-8') as f:
    text = f.read()

# %% [markdown]
# ## Encode text as a bag-of-words using scikit-learn.

# %%
# Using manual tokenizer to split text into words by white space
words = text.split()
# convert to lowercase
words = [word.lower() for word in words]
# create the transform
vectorizer = TfidfVectorizer()
# tokenize and build vocab
vectorizer.fit(words)
# summarize
print(vectorizer.vocabulary_)
print(vectorizer.idf_)

# Let's encode a document
vector = vectorizer.transform([words[0]])

# See the summary of encoded vector
print(vector.shape)
print(vector.toarray())
# Out:
# {'the': 5841, 'project': 4631, 'gutenberg': 2683, 'ebook': 1859, 'of': 4087, 'ideas': 2957, 'good': 2618, 'and': 321, 'evil': 2068, 'this': 5880, 'is': 3198, 'for': 2378, 'use': 6212, 'anyone': 360, 'anywhere': 362, 'in': 3036, 'united': 6147, 'states': 5547, 'most': 3857, 'other': 4155, 'parts': 4267, 'world': 6560, 'at': 482, 'no': 4001, 'cost': 1316, 'with': 6516, 'almost': 276, 'restrictions': 4959, 'whatsoever': 6442, 'you': 6612, 'may': 3668, 'copy': 1296, 'it': 3207, 'give': 2571, 'away': 533, 'or': 4133, 're': 4782, 'under': 6099, 'terms': 5830, 'license': 3431, 'included': 3046, 'online': 4114, 'www': 6599, 'org': 4145, 'if': 2966, 'are': 406, 'not': 4023, 'located': 3499, 'will': 6484, 'have': 2752, 'to': 5942, 'check': 1004, 'laws': 3368, 'country': 1334, 'where': 6448, 'before': 618, 'using': 6220, 'title': 5940, 'author': 511, 'yeats': 6605, 'release': 4879, 'date': 1456, 'june': 3260, '18': 7, '2010': 24, '32884': 39, 'recently': 4816, 'updated': 6203, 'november': 4038,
# ...

# %% [markdown]
# ## Bag-of-Words with Keras

# %%
from keras.preprocessing.text import Tokenizer
# define 5 documents
words = text.split()
t = Tokenizer()
# fit the tokenizer on the documents
t.fit_on_texts(words)
# summarize what was learned
print(t.word_counts)
print(t.document_count)
print(t.word_index)
print(t.word_docs)
# integer encode documents
encoded_docs = t.texts_to_matrix(words, mode='count')
print(encoded_docs)

# %%
# from gensim.models import Word2Vec
# from sklearn.decomposition import PCA
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from gensim.models import Word2Vec
#       2 from sklearn.decomposition import PCA
#
# File c:\Users\DELL\anaconda3\envs\mltools\Lib\site-packages\gensim\__init__.py:11
#       7 __version__ = '4.3.2'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File c:\Users\DELL\anaconda3\envs\mltools\Lib\site-packages\gensim\corpora\__init__.py:6
#       1 """
#       2 This package contains implementations of various streaming corpus I/O format.
#       3 """
#       5 # bring corpus classes directly into package namespace, to save some typing
# ...
